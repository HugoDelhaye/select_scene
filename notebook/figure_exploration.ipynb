# %%
import os
import sys
import pandas as pd

# Add code directory to Python path
notebook_dir = os.getcwd()
sys.path.append(os.path.join(notebook_dir, "..", "code"))

import dashboard

# %% [markdown]
# # Scene Exploration Dashboard
#
# This notebook provides multiple ways to explore learning metrics across scenes, levels, and subjects.
#
# ## Option 1: Dash Web App (Recommended - Better Performance)
#
# Run from terminal:
# ```bash
# python run_dashboard.py
# ```
# Then open http://localhost:8050 in your browser
#
# ## Option 2: Export to HTML (For Sharing)
#
# Export all scenes to standalone HTML files:
# ```bash
# python export_dashboard.py --output-dir html_export
# ```
#
# Export a single scene:
# ```bash
# python export_dashboard.py --level w1l1 --scene 0 --output-dir html_export
# ```
#
# ## Option 3: Jupyter Widgets (Legacy)
#
# Use the cells below for in-notebook exploration.

# %%
# Load metrics data
df = pd.read_parquet('../sourcedata/df_metrics.parquet')
print(f"Loaded {len(df)} rows from metrics data")
df.head()
# Out:
# Loaded 14500 rows from metrics data
#      subject            learning_phase scene_full_name  delta_clr_tot  \
# 0  im_sub-06  sub-06_epoch=0-step=2000           6-3-8       0.000000
# 1  im_sub-06  sub-06_epoch=0-step=2000           6-3-6      -0.633333
# 2  im_sub-06  sub-06_epoch=0-step=2000           7-3-4       0.877193
# 3  im_sub-06  sub-06_epoch=0-step=2000           6-1-7       0.346154
# 4  im_sub-06  sub-06_epoch=0-step=2000          6-2-13       0.000000
#
#    delta_spd_tot  delta_MAD_tot  count   cleared       speed  MAD_mean  \
# 0      -5.114034            NaN   35.0  0.000000    5.113232       NaN
# 1     -54.833397            NaN   30.0  0.066667    4.888235       NaN
# 2      74.317809            NaN   57.0  0.771930  123.018701       NaN
# 3      48.959562            NaN   26.0  0.692308  107.614981       NaN
# 4      -1.399093            NaN   31.0  0.129032   11.897219       NaN
#
#   level_full_name  scene
# 0            w6l3      8
# 1            w6l3      6
# 2            w7l3      4
# 3            w6l1      7
# 4            w6l2     13

# %%
# Option A: Run legacy Jupyter widgets dashboard (slower)
# dashboard.run_dashboard(df)

# Option B: Export to HTML (run this once, then open html_export/index.html)
from export_html import export_all_scenes
# export_all_scenes(df, output_dir='../html_export')

# Option C: Export a single scene to HTML for quick preview
from export_html import export_single_scene
# export_single_scene(df, 'w1l1', 0, '../html_export/preview.html')
# print("Preview exported! Open html_export/preview.html in your browser")

print("Uncomment one of the options above to use it.")
print("\nRecommended: Run 'python ../run_dashboard.py' from terminal for best experience!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Option A: Run legacy Jupyter widgets dashboard (slower)
#       2 # dashboard.run_dashboard(df)
#       3
#       4 # Option B: Export to HTML (run this once, then open html_export/index.html)
# ----> 5 from export_html import export_all_scenes
#       6 # export_all_scenes(df, output_dir='../html_export')
#       7
#       8 # Option C: Export a single scene to HTML for quick preview
#       9 from export_html import export_single_scene
#
# ModuleNotFoundError: No module named 'export_html'
